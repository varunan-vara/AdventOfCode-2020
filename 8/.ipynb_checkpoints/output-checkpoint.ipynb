# %%
#import
import re


instructionspart1 = """
--- Day 8: Handheld Halting ---

Your flight to the major airline hub reaches cruising altitude without incident. While you consider checking the in-flight menu for one of those drinks that come with a little umbrella, you are interrupted by the kid sitting next to you.

Their handheld game console won't turn on! They ask if you can take a look.

You narrow the problem down to a strange infinite loop in the boot code (your puzzle input) of the device. You should be able to fix it, but first you need to be able to run the code in isolation.

The boot code is represented as a text file with one instruction per line of text. Each instruction consists of an operation (acc, jmp, or nop) and an argument (a signed number like +4 or -20).

    acc increases or decreases a single global value called the accumulator by the value given in the argument. For example, acc +7 would increase the accumulator by 7. The accumulator starts at 0. After an acc instruction, the instruction immediately below it is executed next.
    jmp jumps to a new instruction relative to itself. The next instruction to execute is found using the argument as an offset from the jmp instruction; for example, jmp +2 would skip the next instruction, jmp +1 would continue to the instruction immediately below it, and jmp -20 would cause the instruction 20 lines above to be executed next.
    nop stands for No OPeration - it does nothing. The instruction immediately below it is executed next.

For example, consider the following program:

nop +0
acc +1
jmp +4
acc +3
jmp -3
acc -99
acc +1
jmp -4
acc +6

These instructions are visited in this order:

nop +0  | 1
acc +1  | 2, 8(!)
jmp +4  | 3
acc +3  | 6
jmp -3  | 7
acc -99 |
acc +1  | 4
jmp -4  | 5
acc +6  |

First, the nop +0 does nothing. Then, the accumulator is increased from 0 to 1 (acc +1) and jmp +4 sets the next instruction to the other acc +1 near the bottom. After it increases the accumulator from 1 to 2, jmp -4 executes, setting the next instruction to the only acc +3. It sets the accumulator to 5, and jmp -3 causes the program to continue back at the first acc +1.

This is an infinite loop: with this sequence of jumps, the program will run forever. The moment the program tries to run any instruction a second time, you know it will never terminate.

Immediately before the program would run an instruction a second time, the value in the accumulator is 5.

Run your copy of the boot code. Immediately before any instruction is executed a second time, what value is in the accumulator?
"""

# %%
#Read lines 
file_handle = open("input.txt","r")
#Put files from text file into list
_actionlist = file_handle.readlines()
#Create new list
actionlist = []
tempactionlist = []
#Convert string to string
for action in _actionlist:
    #Regex - organize
    pattern = r"\n"
    actionstr = re.sub(pattern, "", action)
    tempactionlist.append(actionstr)

# %%
#Create class action
class ActionResponse:
    def __init__(self, accumulator, change):
        self.accumulator = accumulator
        self.change = change
class Action:
    def __init__(self, statement):
        newt = statement.strip().split(" ")
        self.instruction = newt[0]
        self.operation = newt[1]
        #Performs required action, returns which line, relative to itself, should be performed
    def performAction(self):
        if (self.instruction == "acc"):
            return ActionResponse(self.operation, "+1")
        if (self.instruction == "jmp"):
            return ActionResponse("0", self.operation)
        if (self.instruction == "nop"):
            return ActionResponse("0","+1")
            print("Accumulator 0, Change +1")
for action in tempactionlist:
    submit = Action(action)
    actionlist.append(submit)
#for action in actionlist:
    # print(action.instruction + " " + action.operation)

# %%
#Create function that operates Game Console until loop
def GameConsole():
    #Create Variables
    accumulator = 0
    currentaction = 0
    visitednumbers = []
    notloop = True
    while notloop:
        if (currentaction in visitednumbers):
            print(visitednumbers)
            print("Looping Action: " + str(currentaction))
            break
        else:
            print("Currently Performing Action: " + str(currentaction))
            visitednumbers.append(currentaction)
            boom = actionlist[currentaction].performAction()
            accumulator += int(boom.accumulator)
            print("Accumulator Update: " + str(accumulator))
            currentaction += int(boom.change)
        print(visitednumbers)
GameConsole()
# Out:
# Currently Performing Action: 0
# Accumulator Update: -8
# [0]
# Currently Performing Action: 1
# Accumulator Update: 11
# [0, 1]
# Currently Performing Action: 2
# Accumulator Update: 11
# [0, 1, 2]
# Currently Performing Action: 3
# Accumulator Update: 11
# [0, 1, 2, 3]
# Currently Performing Action: 496
# Accumulator Update: 16
# [0, 1, 2, 3, 496]
# Currently Performing Action: 497
# Accumulator Update: 27
# [0, 1, 2, 3, 496, 497]
# Currently Performing Action: 498
# Accumulator Update: 47
# [0, 1, 2, 3, 496, 497, 498]
# Currently Performing Action: 499
# Accumulator Update: 85
# [0, 1, 2, 3, 496, 497, 498, 499]
# Currently Performing Action: 500
# Accumulator Update: 85
# [0, 1, 2, 3, 496, 497, 498, 499, 500]
# Currently Performing Action: 403
# Accumulator Update: 118
# [0, 1, 2, 3, 496, 497, 498, 499, 500, 403]
# Currently Performing Action: 404
# Accumulator Update: 118
# [0, 1, 2, 3, 496, 497, 498, 499, 500, 403, 404]
# Currently Performing Action: 74
# ...

# %%
#THEREFORE the accumulator was at 2080 before looping

# %%
instructionspart2 = """
--- Part Two ---

After some careful analysis, you believe that exactly one instruction is corrupted.

Somewhere in the program, either a jmp is supposed to be a nop, or a nop is supposed to be a jmp. (No acc instructions were harmed in the corruption of this boot code.)

The program is supposed to terminate by attempting to execute an instruction immediately after the last instruction in the file. By changing exactly one jmp or nop, you can repair the boot code and make it terminate correctly.

For example, consider the same program from above:

nop +0
acc +1
jmp +4
acc +3
jmp -3
acc -99
acc +1
jmp -4
acc +6

If you change the first instruction from nop +0 to jmp +0, it would create a single-instruction infinite loop, never leaving that instruction. If you change almost any of the jmp instructions, the program will still eventually find another jmp instruction and loop forever.

However, if you change the second-to-last instruction (from jmp -4 to nop -4), the program terminates! The instructions are visited in this order:

nop +0  | 1
acc +1  | 2
jmp +4  | 3
acc +3  |
jmp -3  |
acc -99 |
acc +1  | 4
nop -4  | 5
acc +6  | 6

After the last instruction (acc +6), the program terminates by attempting to run the instruction below the last instruction in the file. With this change, after the program terminates, the accumulator contains the value 8 (acc +1, acc +1, acc +6).

Fix the program so that it terminates normally by changing exactly one jmp (to nop) or nop (to jmp). What is the value of the accumulator after the program terminates?
"""

# %%
#New list to account for potential errors
potentialerrors = []
#Copy of Game Console, with minor tweaks to accomplish this program
def GameConsole():
    #Create Variables
    accumulator = 0
    currentaction = 0
    visitednumbers = []
    notloop = True
    while notloop:
        if (currentaction in visitednumbers):
            print(visitednumbers)
            print("Looping Action: " + str(currentaction))
            break
        else:
            print("Currently Performing Action: " + str(currentaction))
            visitednumbers.append(currentaction)
            boom = actionlist[currentaction].performAction()
            if (actionlist[currentaction].instruction != "acc"):
                potentialerrors.append(currentaction)
            accumulator += int(boom.accumulator)
            print("Accumulator Update: " + str(accumulator))
            currentaction += int(boom.change)
        print(visitednumbers)
        print("List of potentialerrors: \n" + str(potentialerrors))
GameConsole()
# Out:
# Currently Performing Action: 0
# Accumulator Update: 0
# [0]
# Currently Performing Action: 1
# Accumulator Update: 19
# [0, 1]
# Currently Performing Action: 2
# Accumulator Update: 19
# [0, 1, 2]
# Currently Performing Action: 3
# Accumulator Update: 19
# [0, 1, 2, 3]
# Currently Performing Action: 4
# Accumulator Update: 26
# [0, 1, 2, 3, 4]
# Currently Performing Action: 5
# Accumulator Update: 26
# [0, 1, 2, 3, 4, 5]
# Currently Performing Action: 272
# Accumulator Update: 75
# [0, 1, 2, 3, 4, 5, 272]
# Currently Performing Action: 273
# Accumulator Update: 75
# [0, 1, 2, 3, 4, 5, 272, 273]
# Currently Performing Action: 274
# Accumulator Update: 75
# [0, 1, 2, 3, 4, 5, 272, 273, 274]
# Currently Performing Action: 392
# Accumulator Update: 62
# [0, 1, 2, 3, 4, 5, 272, 273, 274, 392]
# Currently Performing Action: 393
# Accumulator Update: 53
# [0, 1, 2, 3, 4, 5, 272, 273, 274, 392, 393]
# Currently Performing Action: 394
# Accumulator Update: 57
# ...

# %%
currentaction = 0
testingvalue = 0
listmaid = []
#Modified GameConsole that runs attempted corrected code, and reports on any errors
def GameConsole(inputlist):
    #Create Variables
    accumulator = 0
    currentaction = 0
    visitednumbers = []
    notloop = True
    while notloop:
        print(accumulator)
        if (currentaction in visitednumbers):
            #print(visitednumbers)
            return 0
            listmaid.append(currentaction)
            break
        else:
            if (currentaction > len(inputlist)):
                return 1
                break
            else:
                #print("Currently Performing Action: " + str(currentaction))
                visitednumbers.append(currentaction)
                boom = inputlist[currentaction].performAction()
                accumulator += int(boom.accumulator)
                #print("Accumulator Update: " + str(accumulator))
                currentaction += int(boom.change)
        #print(visitednumbers)
#Create a function that returns a new list with 1 modification
#potentialerrors = list of areas where an error may occur
for error in potentialerrors:
    print("-----------------------------currently testing error #: " + str(error))
    newlist = actionlist
    if (newlist[error].instruction == "jmp"):
        newlist[error].instruction = "nop"
    else:
        newlist[error].instruction = "jmp"
    message1 = "------Looping, will restart machine------"
    message2 = "------Successfully launched Game Console, change at: " + str(error) + "------"
    if (GameConsole(newlist) == 1):
        print(message2)
        break
    else:
        print(message1)
# Out:
# -----------------------------currently testing error #: 0
# 0
# 0
# 19
# 19
# 19
# 26
# 26
# 75
# 75
# 75
# 62
# 53
# 57
# 57
# 41
# 43
# 43
# 85
# 85
# 130
# 170
# 170
# 220
# 220
# 220
# 220
# 220
# 220
# 220
# 240
# 259
# 295
# 295
# 338
# 344
# 354
# 354
# 354
# 354
# 393
# 418
# 404
# 405
# 405
# 405
# 405
# 447
# 489
# 515
# 515
# 538
# 538
# 562
# 592
# 592
# 592
# 601
# 601
# 621
# 659
# 659
# 659
# 659
# 659
# 699
# 744
# 786
# 782
# 782
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-33-b042892b20db> in <module>
#      39     message1 = "------Looping, will restart machine------"
#      40     message2 = "------Successfully launched Game Console, change at: " + str(error) + "------"
# ---> 41     if (GameConsole(newlist) == 1):
#      42         print(message2)
#      43         break
#
# <ipython-input-33-b042892b20db> in GameConsole(inputlist)
# ...
